# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Previewing data

# %%
#Preview of the data
covid_df = pd.read_csv('us_covid19_daily.csv')
pd.set_option('display.max_columns', None)
covid_df.head(5)
# Out:
#        date  states  positive   negative  pending  hospitalizedCurrently  \
# 0  20201206      56  14534035  161986294  13592.0               101487.0
# 1  20201205      56  14357264  160813704  13433.0               101190.0
# 2  20201204      56  14146191  159286709  12714.0               101276.0
# 3  20201203      56  13921360  158026052  15106.0               100755.0
# 4  20201202      56  13711156  156787587  14368.0               100322.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                585676.0         20145.0          31946.0
# 1                583420.0         19950.0          31831.0
# 2                580104.0         19858.0          31608.0
# 3                575452.0         19723.0          31276.0
# 4                570121.0         19680.0          31038.0
#
#    onVentilatorCurrently  onVentilatorCumulative  recovered  \
# 0                 7094.0                  3322.0  5624444.0
# 1                 7005.0                  3321.0  5576026.0
# 2                 6999.0                  3305.0  5470389.0
# 3                 6867.0                  3280.0  5404018.0
# 4                 6855.0                  3252.0  5322128.0
#
#             dateChecked     death  hospitalized  totalTestResults  \
# 0  2020-12-06T24:00:00Z  273374.0      585676.0         204063869
# 1  2020-12-05T24:00:00Z  272236.0      583420.0         202429337
# 2  2020-12-04T24:00:00Z  269791.0      580104.0         200259581
# 3  2020-12-03T24:00:00Z  267228.0      575452.0         198404712
# 4  2020-12-02T24:00:00Z  264522.0      570121.0         196576482
#
#            lastModified  total  posNeg  deathIncrease  hospitalizedIncrease  \
# 0  2020-12-06T24:00:00Z      0       0           1138                  2256
# 1  2020-12-05T24:00:00Z      0       0           2445                  3316
# 2  2020-12-04T24:00:00Z      0       0           2563                  4652
# 3  2020-12-03T24:00:00Z      0       0           2706                  5331
# 4  2020-12-02T24:00:00Z      0       0           2733                  5028
#
#    negativeIncrease  positiveIncrease  totalTestResultsIncrease  \
# 0           1172590            176771                   1634532
# 1           1526995            211073                   2169756
# 2           1260657            224831                   1854869
# 3           1238465            210204                   1828230
# 4            982032            195796                   1459202
#
#                                        hash
# 0  9cf16504f91958e803a2197daf8c2528a4eddc18
# 1  6249216c5f097c94ce33a811dab011a483a42404
# 2  ae30ea088584335ba4d57ee927f8dbda6add74db
# 3  0f253d185ecb336cdd18a4c61996eda1b7eef13b
# 4  477c17b6302d0485195e77ecf8270a974f7a3c82

# %%
print(covid_df.columns)
print("\nNumber of rows and columns" + str(covid_df.shape) )
#Dataset has 320 rows and 25 columns
# Out:
# Index(['date', 'states', 'positive', 'negative', 'pending',
#        'hospitalizedCurrently', 'hospitalizedCumulative', 'inIcuCurrently',
#        'inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative',
#        'recovered', 'dateChecked', 'death', 'hospitalized', 'totalTestResults',
#        'lastModified', 'total', 'posNeg', 'deathIncrease',
#        'hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease',
#        'totalTestResultsIncrease', 'hash'],
#       dtype='object')
#
# Number of rows and columns(320, 25)

# %% [markdown]
# # Dropping non essential columns

# %%
#Removal of non essential columns (useless columns)
cols_to_drop=['states','pending','dateChecked','lastModified','total','posNeg','hash']
covid_df.drop(columns=cols_to_drop, inplace=True)
print(covid_df.columns)
print(len(covid_df.columns))
# Out:
# Index(['date', 'positive', 'negative', 'hospitalizedCurrently',
#        'hospitalizedCumulative', 'inIcuCurrently', 'inIcuCumulative',
#        'onVentilatorCurrently', 'onVentilatorCumulative', 'recovered', 'death',
#        'hospitalized', 'totalTestResults', 'deathIncrease',
#        'hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease',
#        'totalTestResultsIncrease'],
#       dtype='object')
# 18

# %%
#Since we are monitoring the relation between covid and increases in stock DAILY, cummulative variables will be dropped
cum_cols_drop=['hospitalizedCumulative','inIcuCumulative','onVentilatorCumulative',]
covid_df.drop(columns=cum_cols_drop, inplace=True)
print(covid_df.columns)
print(len(covid_df.columns))
# Out:
# Index(['date', 'positive', 'negative', 'hospitalizedCurrently',
#        'inIcuCurrently', 'onVentilatorCurrently', 'recovered', 'death',
#        'hospitalized', 'totalTestResults', 'deathIncrease',
#        'hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease',
#        'totalTestResultsIncrease'],
#       dtype='object')
# 15

# %%
# To avoid overfitting,unrelated variables to stocks will be dropped
# Purpose: Generalize covid situation
ntrelated_cols = ['inIcuCurrently','onVentilatorCurrently']
covid_df.drop(columns=ntrelated_cols, inplace=True)
print(covid_df.columns)
print(len(covid_df.columns))
# Out:
# Index(['date', 'positive', 'negative', 'hospitalizedCurrently', 'recovered',
#        'death', 'hospitalized', 'totalTestResults', 'deathIncrease',
#        'hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease',
#        'totalTestResultsIncrease'],
#       dtype='object')
# 13

# %% [markdown]
# # Inverting dataset due to reversed date order

# %%
#Since the dates for the dataset is from latest to oldest, the order of the datset will be inverted
covid_df = covid_df[::-1].reset_index(drop=True)
covid_df.head(3)
# Out:
#        date  positive  negative  hospitalizedCurrently  recovered  death  \
# 0  20200122         0         0                    NaN        NaN    NaN
# 1  20200123         0         0                    NaN        NaN    NaN
# 2  20200124         0         0                    NaN        NaN    NaN
#
#    hospitalized  totalTestResults  deathIncrease  hospitalizedIncrease  \
# 0           NaN                 1              0                     0
# 1           NaN                 2              0                     0
# 2           NaN                 2              0                     0
#
#    negativeIncrease  positiveIncrease  totalTestResultsIncrease
# 0                 0                 0                         0
# 1                 0                 0                         1
# 2                 0                 0                         0

# %% [markdown]
# # Converting date to datetime format

# %%
covid_df['date'] = pd.to_datetime(covid_df['date'], format='%Y%m%d')
covid_df.head(50)
# Out:
#          date  positive  negative  hospitalizedCurrently  recovered  death  \
# 0  2020-01-22         0         0                    NaN        NaN    NaN
# 1  2020-01-23         0         0                    NaN        NaN    NaN
# 2  2020-01-24         0         0                    NaN        NaN    NaN
# 3  2020-01-25         0         0                    NaN        NaN    NaN
# 4  2020-01-26         0         0                    NaN        NaN    NaN
# 5  2020-01-27         0         0                    NaN        NaN    NaN
# 6  2020-01-28         0         0                    NaN        NaN    NaN
# 7  2020-01-29         0         0                    NaN        NaN    NaN
# 8  2020-01-30         0         0                    NaN        NaN    NaN
# 9  2020-01-31         0         0                    NaN        NaN    NaN
# 10 2020-02-01         0         0                    NaN        NaN    NaN
# 11 2020-02-02         0         0                    NaN        NaN    NaN
# 12 2020-02-03         0         0                    NaN        NaN    NaN
# 13 2020-02-04         0         0                    NaN        NaN    NaN
# 14 2020-02-05         0         0                    NaN        NaN    NaN
# 15 2020-02-06         0         0                    NaN        NaN    NaN
# 16 2020-02-07         0         0                    NaN        NaN    NaN
# 17 2020-02-08         0         0                    NaN        NaN    NaN
# 18 2020-02-09         0         0                    NaN        NaN    NaN
# 19 2020-02-10         0         0                    NaN        NaN    0.0
# 20 2020-02-11         0         0                    NaN        NaN    0.0
# 21 2020-02-12         0         0                    NaN        NaN    0.0
# 22 2020-02-13         0         0                    NaN        NaN    0.0
# 23 2020-02-14         0         0                    NaN        NaN    0.0
# 24 2020-02-15         0         0                    NaN        NaN    0.0
# 25 2020-02-16         0         0                    NaN        NaN    0.0
# 26 2020-02-17         0         0                    NaN        NaN    0.0
# 27 2020-02-18         0         0                    NaN        NaN    0.0
# 28 2020-02-19         0         0                    NaN        NaN    0.0
# 29 2020-02-20         0         0                    NaN        NaN    0.0
# 30 2020-02-21         0         0                    NaN        NaN    0.0
# 31 2020-02-22         0         0                    NaN        NaN    0.0
# 32 2020-02-23         0         0                    NaN        NaN    0.0
# 33 2020-02-24         0         0                    NaN        NaN    0.0
# 34 2020-02-25         0         0                    NaN        NaN    0.0
# 35 2020-02-26         0         0                    NaN        NaN    2.0
# 36 2020-02-27         0         0                    NaN        NaN    2.0
# 37 2020-02-28         0         0                    NaN        NaN    4.0
# 38 2020-02-29        18        24                    NaN        NaN    5.0
# 39 2020-03-01        50        85                    NaN        NaN    8.0
# 40 2020-03-02        94       243                    NaN        NaN   11.0
# 41 2020-03-03       145       446                    NaN        NaN   14.0
# 42 2020-03-04       279      1397                    NaN        NaN   16.0
# 43 2020-03-05       367      1943                    NaN        NaN   20.0
# 44 2020-03-06       497      2718                    NaN        NaN   26.0
# 45 2020-03-07       631      3432                    NaN        NaN   27.0
# 46 2020-03-08       827      4342                    NaN        NaN   31.0
# 47 2020-03-09      1112      6144                    NaN        NaN   35.0
# 48 2020-03-10      1551      8765                    NaN        NaN   37.0
# 49 2020-03-11      2053     12573                    NaN        NaN   43.0
#
#     hospitalized  totalTestResults  deathIncrease  hospitalizedIncrease  \
# 0            NaN                 1              0                     0
# 1            NaN                 2              0                     0
# 2            NaN                 2              0                     0
# 3            NaN                 2              0                     0
# 4            NaN                 2              0                     0
# 5            NaN                 3              0                     0
# 6            NaN                 3              0                     0
# 7            NaN                 5              0                     0
# 8            NaN                 5              0                     0
# 9            NaN                 8              0                     0
# 10           NaN                 8              0                     0
# 11           NaN                 8              0                     0
# 12           NaN                11              0                     0
# 13           NaN                15              0                     0
# 14           NaN                15              0                     0
# 15           NaN                16              0                     0
# 16           NaN                16              0                     0
# 17           NaN                18              0                     0
# 18           NaN                18              0                     0
# 19           NaN                19              0                     0
# 20           NaN                20              0                     0
# 21           NaN                21              0                     0
# 22           NaN                22              0                     0
# 23           NaN                22              0                     0
# 24           NaN                26              0                     0
# 25           NaN                28              0                     0
# 26           NaN                29              0                     0
# 27           NaN                29              0                     0
# 28           NaN                35              0                     0
# 29           NaN                36              0                     0
# 30           NaN                37              0                     0
# 31           NaN                38              0                     0
# 32           NaN                38              0                     0
# 33           NaN                40              0                     0
# 34           NaN                41              0                     0
# 35           NaN                41              2                     0
# 36           NaN              6487              0                     0
# 37           NaN              6490              2                     0
# 38           NaN              6552              1                     0
# 39           NaN              6661              3                     0
# 40           NaN              6873              3                     0
# 41           NaN              7165              3                     0
# 42           4.0              8206              2                     4
# 43           5.0              8863              4                     1
# 44           6.0              9824              6                     1
# 45           6.0             10779              1                     0
# 46           6.0             11961              4                     0
# 47           9.0             14150              4                     3
# 48           9.0             17299              2                     0
# 49          12.0             21913              6                     3
#
#     negativeIncrease  positiveIncrease  totalTestResultsIncrease
# 0                  0                 0                         0
# 1                  0                 0                         1
# 2                  0                 0                         0
# 3                  0                 0                         0
# 4                  0                 0                         0
# 5                  0                 0                         1
# 6                  0                 0                         0
# 7                  0                 0                         2
# 8                  0                 0                         0
# 9                  0                 0                         3
# 10                 0                 0                         0
# 11                 0                 0                         0
# 12                 0                 0                         3
# 13                 0                 0                         4
# 14                 0                 0                         0
# 15                 0                 0                         1
# 16                 0                 0                         0
# 17                 0                 0                         2
# 18                 0                 0                         0
# 19                 0                 0                         1
# 20                 0                 0                         1
# 21                 0                 0                         1
# 22                 0                 0                         1
# 23                 0                 0                         0
# 24                 0                 0                         4
# 25                 0                 0                         2
# 26                 0                 0                         1
# 27                 0                 0                         0
# 28                 0                 0                         6
# 29                 0                 0                         1
# 30                 0                 0                         1
# 31                 0                 0                         1
# 32                 0                 0                         0
# 33                 0                 0                         2
# 34                 0                 0                         1
# 35                 0                 0                         0
# 36                 0                 0                      6446
# 37                 0                 0                         3
# 38                24                18                        62
# 39                61                32                       109
# 40               158                44                       212
# 41               203                51                       292
# 42               951               134                      1041
# 43               546                88                       657
# 44               775               130                       961
# 45               714               134                       955
# 46               910               196                      1182
# 47              1802               285                      2189
# 48              2621               439                      3149
# 49              3808               502                      4614

# %% [markdown]
# # Dropping rows with nan values

# %%
#Rows with nan values will be dropped , these columns have Nan Values , resulting from the beginning of covid cases
covid_df= covid_df.dropna().reset_index(drop=True)
covid_df.head(4)
# Out:
#         date  positive  negative  hospitalizedCurrently  recovered   death  \
# 0 2020-03-25     75242    395632                 5140.0      146.0  1058.0
# 1 2020-03-26     92976    482148                 7805.0       97.0  1374.0
# 2 2020-03-27    112220    559423                10978.0     2418.0  1782.0
# 3 2020-03-28    131826    657185                12409.0     3145.0  2333.0
#
#    hospitalized  totalTestResults  deathIncrease  hospitalizedIncrease  \
# 0        7073.0            524577            238                  1949
# 1        9551.0            632999            316                  2478
# 2       12123.0            735114            408                  2572
# 3       14532.0            835570            551                  2409
#
#    negativeIncrease  positiveIncrease  totalTestResultsIncrease
# 0             70882             12891                     89096
# 1             86516             17734                    108422
# 2             77275             19244                    102115
# 3             97762             19606                    100456

# %% [markdown]
# Notice that the dates start from 25th  of march instead of our original previous date, this reflects normal covid conditions, where there are people admitted to hospitals, recover, etc.

# %%
#Used for checking additional null values
covid_df.isnull().sum()
# Out:
# date                        0
# positive                    0
# negative                    0
# hospitalizedCurrently       0
# recovered                   0
# death                       0
# hospitalized                0
# totalTestResults            0
# deathIncrease               0
# hospitalizedIncrease        0
# negativeIncrease            0
# positiveIncrease            0
# totalTestResultsIncrease    0
# dtype: int64

# %%
covid_df.to_csv('covid_df_preprocessed.csv', index=False)
